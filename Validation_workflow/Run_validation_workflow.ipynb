# %% [markdown]
#  # **VALIDATION WORKFLOW**

# %% [markdown]
# **Imports:**

# %%
import sys
from pathlib import Path

# Set path of the project as root
PROJECT_ROOT = Path("..").resolve()
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from run_validation import main

# %% [markdown]
# **Run validation workflow:**

# %%
df_pipes, df_cctv, df_defects, df_hydraulics, output_dir = main(
    source_type="database",
    source_path=Path("../../1.Database_structure/Sewer_Database_UoA8.db"),
    sheet_names=None,
    output_dir=Path("Validation_Results"),
    auto_open_report=True,
    open_containing_folder=True
)
# Out:
#               Entity  Errors  Warnings
#                PIPES    4148    606204
#                 CCTV       0      3885
#              DEFECTS       0      4144
# HYDRAULIC_PROPERTIES   87248       209
#
# A validation report was generated at:
# Validation_Results\Summary.xlsx
